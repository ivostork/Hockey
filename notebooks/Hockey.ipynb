# %% [markdown]
# # Datová analytika - vytvoření sázkových kurzů
# ## Cíl
#
# Úkolem bude získat výsledky NHL z veřejně dostupných zdrojů a následně určit počáteční sázkové kurzy.
#
# Čtyři hlavní částí tohoto notebooku:
#
# - **1. Stažení dat** – stáhneme data ze stránky Scrape This Site (část 1),
#
# - **2. Zpracování dat** – budeme analyzovat HTML a připravíme data pro analýzu (část 2),
#
# - **3. Analýza dat** – provedeme explorační analýzu dat, abychom se seznámili s jejich charakteristikami (část 3),
#
# - **4. Výsledek** – vytvoříme počáteční sázkové kurzy (část 4).
#
# ---
#
# ## Požadované knihovny
#
# - **requests** – pro stažení HTML obsahu stránek se zápasy,
#
# - **BeautifulSoup** – pro zpracování nestrukturovaných dat (HTML kódu) do tabulární podoby (DataSet),
#
# - **Pandas** – pro provádění transformací dat,
#
# - **Matplotlib** – pro prezentaci výsledků.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from time import sleep
from glob import glob
import json
from glob import glob

# %% [markdown]
# ---
# ## Stažení dat

# %%
# URL
url = 'https://www.scrapethissite.com/pages/forms/?per_page=100'

try:
    # Vytvor request
    response = requests.get(url)
    response.raise_for_status()

    # Najdi vsechny url adresy, ke vsem tabulkam
    



except requests.exceptions.HTTPError as err:
    print(f"HTTP chyba nastala: {err}")
except Exception as err:
    print(f"Jiná chyba: {err}")
